# %% [markdown]
# # Practice 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

np.random.seed(42)

# %%
def liner_fuction(x, a, b):
    return a * x + b

# %%
n_sample = 10

a = 2
b = 3
noise_mean = 0
noise_std = 2
noise = np.random.normal(noise_mean, noise_std, n_sample)

x = np.linspace(1, 10, n_sample, endpoint=True)
y = liner_fuction(x, a, b) + noise

# %%
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Noised Samples')
plt.savefig('./figures/practice_2_1_original_samples.pdf', transparent=True, bbox_inches='tight')
plt.show()

# %%
propt, _ = curve_fit(liner_fuction, x, y)
print(f'a: {a} -> {propt[0]}')
print(f'b: {b} -> {propt[1]}')
# Out:
# a: 2 -> 1.9861992566322368
# b: 3 -> 3.9720263119202106

# %%
residuals = y - liner_fuction(x, *propt)

# %%
plt.scatter(x, y, label=f'Samples: y = {a}x + {b} + noise')
plt.plot(x, liner_fuction(x, *propt), color='red', label=f'Fitted line: y = {propt[0]:.2f}x + {propt[1]:.2f}')
for i in range(n_sample):
    plt.plot([x[i], x[i]], [y[i], liner_fuction(x[i], *propt)], color='k', linestyle='--', label='Residuals' if i == 0 else None)
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Noised Samples with Fitted Line')
plt.legend()
plt.savefig('./figures/practice_2_1_fitted_line.pdf', transparent=True, bbox_inches='tight')
plt.show()

# %%
# Calculate the residuals
residuals = y - liner_fuction(x, *propt)

# Plot the residuals
plt.scatter(x, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('x')
plt.ylabel('Residuals')
plt.title('Residuals Plot')
plt.savefig('./figures/practice_2_1_residuals.pdf', transparent=True, bbox_inches='tight')
plt.show()
